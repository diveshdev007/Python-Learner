# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
demo = Image.open(r'C:\Users\dives\OneDrive\Desktop\ind.jpg')

# %%
demo
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x850>

# %%
type(demo)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
demo_arr = np.asarray(demo)
demo_arr
# Out:
# array([[[254, 170,  35],
#         [253, 169,  34],
#         [253, 170,  32],
#         ...,
#         [240, 151,  61],
#         [240, 151,  61],
#         [239, 150,  60]],
#
#        [[253, 169,  34],
#         [253, 169,  34],
#         [253, 169,  34],
#         ...,
#         [241, 152,  62],
#         [240, 151,  61],
#         [240, 151,  61]],
#
#        [[253, 169,  34],
#         [253, 169,  34],
#         [253, 169,  34],
#         ...,
#         [242, 151,  62],
#         [242, 151,  62],
#         [242, 151,  62]],
#
#        ...,
#
#        [[226, 132,  32],
#         [229, 135,  35],
#         [232, 135,  38],
#         ...,
#         [219, 133,  48],
#         [216, 132,  46],
#         [215, 131,  45]],
#
#        [[204, 116,  42],
#         [203, 117,  44],
#         [198, 116,  42],
#         ...,
#         [221, 129,  46],
#         [221, 129,  46],
#         [219, 127,  44]],
#
#        [[213, 125,  51],
#         [211, 125,  52],
#         [205, 123,  49],
# ...

# %%
type(demo_arr)
# Out:
# numpy.ndarray

# %%
demo_arr.shape
# Out:
# (850, 1280, 3)

# %%
plt.imshow(demo)
